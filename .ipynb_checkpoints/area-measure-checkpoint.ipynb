# %% [markdown]
# ### Size measurer -- Work in progress
#
# #### Segments the image to find shapes and measures their area (in pixels)

# %% [markdown]
# TODO:
# - Finish till get areas
# - Later: show intermediate thresholds more neatly in grid form
# - Try HSV channels if get better separation
# - write introduction giving context around the problem

# %% [markdown]
# #### Step 1: Setting up, load the image

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
filepath = './pillbox/uneven1.jpg' #the . at the beginning is important
            # else imread later fails silently

# %%
img = cv2.imread(filepath)

# %%
img.shape #just checking that it loaded fine; imread fails silently
# Out:
# (1944, 2592, 3)

# %%
plt.imshow(img)

# %% [markdown]
# The above is an unfortunate background, but was sleepy and had to take the pill and go back to sleep. So just grabbed what was the only dark flat surface nearby for a quick photo. But would be interesting to segment this.

# %% [markdown]
# #### Step 2: Investigate image, Rough Segmentation

# %%
# let's see the image histogram to understand the intensity distribution
plt.hist(img.ravel(), 256, [0,256])
plt.show()

# %% [markdown]
# The above is a heavily left-skewed distribution. It isn't bimodal, so doesn't present a convenient breakpoint for thresholding. Mostly grays. There's a plateau after 200, that could be our pills. Let's investigate.

# %%
imggray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
ret, thresh = cv2.threshold(imggray, 220, 255, cv2.THRESH_BINARY)

# %%
plt.imshow(thresh, 'gray')

# %% [markdown]
# Just the shiny bottoms of the pills. But at least the background has been completely removed. No diagonal lines as feared.

# %%
ret, thresh = cv2.threshold(imggray, 200, 255, cv2.THRESH_BINARY)
plt.imshow(thresh, 'gray')

# %%
ret, thresh = cv2.threshold(imggray, 180, 255, cv2.THRESH_BINARY)
plt.imshow(thresh, 'gray')

# %%
ret, thresh = cv2.threshold(imggray, 160, 255, cv2.THRESH_BINARY)
plt.imshow(thresh, 'gray')

# %% [markdown]
# Almost there, need to be rid of the pinstripe suit. If there's no clean threshold, might need to use morphological operations or other techniques.

# %%
ret, thresh = cv2.threshold(imggray, 170, 255, cv2.THRESH_BINARY)
plt.imshow(thresh, 'gray')

# %% [markdown]
# Some bits of the pills are missing, and the pinstripe is still there, shows a clean binary threshold isn't possible. After trying more values, found that the 160 already seen above is the first boundary where we can just see the full pills. Going ahead with that.

# %% [markdown]
# #### Step 3: Fine Segmentation

# %% [markdown]
# The image is quite fine resolution. Not needed for our purposes. Resampling it to smaller size would reduce the extent of the pinstripes. Let's try that.

# %%
imggray.shape
# Out:
# (1944, 2592)

# %%
halfsize = imggray.shape[1]//2, imggray.shape[0]//2 # numpy broadcast operations
# didn't work on a tuple for some reason (newsize = imggray.shape/2)
# doing integer division as resize method does not work with floats
# also note the swapping of x & y above
halfsize
# Out:
# (1296, 972)

# %%
imghalf = cv2.resize(imggray, halfsize, interpolation= cv2.INTER_LINEAR)

# %%
plt.imshow(imghalf, 'gray')

# %% [markdown]
# Later or after the above, also try low-pass filters. Also blob detectors inbuilt in OpenCV

# %%
ret, thresh = cv2.threshold(imghalf, 160, 255, cv2.THRESH_BINARY)
plt.imshow(thresh, 'gray')

# %%
# Let's look at a slice up close to see how many pixels the diagonal lines are
# this is the top-left, which is fairly dark already
plt.imshow(thresh[:100, :100], 'gray')

# %%
# lower right
plt.imshow(thresh[-100:, -100:], 'gray')

# %%
plt.imshow(thresh[-200:, -200:], 'gray')

# %%
# lower middle. In general the middle area has the most pronounced lines
# taking the 200 pixels around the midpoint
y,x = thresh.shape
plt.imshow(thresh[x//2-100:x//2+100, y//2-100:y//2+100], 'gray')

# %%
# lower middle. In general the middle area has the most pronounced lines
# taking the 200x200 pixels around the midpoint
y,x = thresh.shape
plt.imshow(thresh[x//2-100:x//2+100, y//2-100:y//2+100], 'gray')

# %%
# 400x400 crop
y,x = thresh.shape
plt.imshow(thresh[x//2-200:x//2+200, y//2-200:y//2+200], 'gray')

# %% [markdown]
# The bigger dots are almost like blobs. The smaller ones are around 4-5 pixels wide. The latter would probably respond to low-pass filters. Bigger ones could need morphological operations

# %% [markdown]
# #### Filtering

# %%
# Low-pass trying a simple kernel first

blur_kernel = np.ones((5, 5)) / 25
blur_img = cv2.filter2D(src=thresh, ddepth=-1, kernel=blur_kernel)
plt.imshow(blur_img, 'gray')

# %%
y,x = blur_img.shape
plt.imshow(blur_img[x//2-100:x//2+100, y//2-100:y//2+100], 'gray')

# %% [markdown]
# The noise is still present, but it has been smudged into a grayer shade. The simplest approach now could be to just threshold it again, since the pills (at least their main body) is still white. Before that, let's look more closely at the pills in the original and low-pass image to see if their edges are affected substantially.

# %%
# from the plots above, it can be seen that the pills are approx in
# 400,600 (height); 600, 800 (width)
plt.subplot(1,2,1)
plt.imshow(thresh[400:600, 600:850], 'gray')
plt.subplot(1,2,2)
plt.imshow(blur_img[400:600, 600:850], 'gray')

# %% [markdown]
# The edges are smudged, but the central areas are still white. The core value we seek (ratio of pill sizes) would still be substantially same.

# %% [markdown]
# Let's check the image histograms, for comparison, and for possible breakpoints for thresholding in the new image.

# %%
plt.subplot(1,2,1)
plt.hist(thresh.ravel(), 256, [0,256])
plt.subplot(1,2,2)
plt.hist(blur_img.ravel(), 256, [0,256])
plt.tight_layout() # without this it seems to crop the right ends, whites not visible
plt.show()

# %% [markdown]
# The black pixels have gotten smudged into 4 shades of gray. White pixels have reduced too. Most of them would be the noise. A few would be pill edges.
#
# The whole span from approx 50-250 is ripe for thresholding anywhere.

# %%
ret, blur_thresh = cv2.threshold(blur_img, 220, 255, cv2.THRESH_BINARY)

# %%
plt.imshow(blur_thresh, 'gray')

# %% [markdown]
# Not perfect, but reasonably good. An alternative approach would have been to use morphological operations to close the smaller noise blobs. But that too would have affected the pills to some extent (the jaggy edge especially).
#
# This is good enough to go ahead with for the present area-finding purposes. The image is binarized.
